# %% [markdown]
# <a href="https://colab.research.google.com/github/JazminAguirre128/Act22-Clase-Mec-nico-Meredith-Aguirre-0013/blob/main/Act22_clase_mecanico_Meredith_Aguirre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Meredith Aguirre NL = 2 Fecha 23/Abril/2026
#
# ![InfoClase](https://raw.githubusercontent.com/JazminAguirre128/Act22-Clase-Mec-nico-Meredith-Aguirre-0013/refs/heads/main/InfoClaseMecanico.png)

# %%
class Mecanico:
    def __init__(self, nombre, telefono, edad):
        # Atributos de la clase
        self.nombre = nombre
        self.telefono = telefono
        self.edad = edad
    # Función 1: Diagnosticar
    def diagnosticar(self, vehiculo):
        print(f"🔧 {self.nombre} está diagnosticando el motor del {vehiculo}...")
    # Función 2: Reparar
    def reparar(self, pieza):
        print(f"🛠️ {self.nombre} está reparando: {pieza}. ¡Quedará como nuevo!")
    # Función 3: Cambio de aceite
    def cambio_aceite(self):
        print(f"🛢️ {self.nombre} está realizando el cambio de aceite y filtro.")
# --- Creación de Objetos (Instancias) ---
# Objeto 1: mecanico1
mecanico1 = Mecanico("Juan Pérez", "555-0123", 35)
# Objeto 2: mecanico2
mecanico2 = Mecanico("Ana Martínez", "555-9876", 28)
# --- Pruebas de funcionamiento ---
print(f"--- Ficha del Mecánico 1: {mecanico1.nombre} ---")
mecanico1.diagnosticar("Sedán azul")
mecanico1.reparar("los frenos")
mecanico1.cambio_aceite()
mecanico1.telefono = "555-5555"
print(f"--- Ficha del Mecánico 2: {mecanico2.nombre} ---")
mecanico2.cambio_aceite()
mecanico2.diagnosticar("SUV rojo")
mecanico2.reparar("el motor")
print(f"Contacto: {mecanico2.telefono}")

print("Programa realizado por Meredith Agurre NL = 2")
# Out:
# --- Ficha del Mecánico 1: Juan Pérez ---
# 🔧 Juan Pérez está diagnosticando el motor del Sedán azul...
# 🛠️ Juan Pérez está reparando: los frenos. ¡Quedará como nuevo!
# 🛢️ Juan Pérez está realizando el cambio de aceite y filtro.
# --- Ficha del Mecánico 2: Ana Martínez ---
# 🛢️ Ana Martínez está realizando el cambio de aceite y filtro.
# 🔧 Ana Martínez está diagnosticando el motor del SUV rojo...
# 🛠️ Ana Martínez está reparando: el motor. ¡Quedará como nuevo!
# Contacto: 555-9876
# Programa realizado por Meredith Agurre NL = 2

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/JazminAguirre128/Act22-Clase-Mec-nico-Meredith-Aguirre-0013/refs/heads/main/TLDrawClaseMecanico.png)
